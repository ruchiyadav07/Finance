# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchiyadav07/Finance/blob/master/Finance1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install quandl
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/9f/5a/d3/6fc3bf6516d2a3eb7e18f9f28b472110b59325f3f258fe9211
# Successfully built inflection
# ...

# %%
import quandl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from matplotlib import style
import pandas_datareader.data as web

# %%
# !pip install nsepy
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/88/89/1e/3dfa14f863314a42481d8926d9ef4825da5d899e026435fc3a
# Successfully built nsepy
# ...

# %%
import nsepy

# %%
# %matplotlib inline

# %%
infy=quandl.get("NSE/INFY", authtoken="xArKxCjktaAm7XGGtxWW")
tcs=quandl.get("NSE/TCS", authtoken="xArKxCjktaAm7XGGtxWW")

# %%
style.use('ggplot')

# %%
'''start=dt.datetime(2016,1,1)
end=dt.datetime(2017,1,1)
df=web.DataReader('INFY','yahoo',start,end)'''
# Out:
# "start=dt.datetime(2000,1,1)\nend=dt.datetime(2017,1,1)\ndf=web.DataReader('INFY','yahoo',start,end)"

# %%
#plt.hist(infy['Turnover (Lacs)'],bins=100)

# %%
infy.columns
# Out:
# Index(['Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
tcs.columns
# Out:
# Index(['Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
infy['30ma']=infy['Open'].rolling(window=30,min_periods=0).mean() //monthly approx
tcs['30ma']=tcs['Open'].rolling(window=30,min_periods=0).mean()

# %%
infy['30ma'].tail()
# Out:
# Date
# 2018-12-31    663.141667
# 2019-01-01    663.176667
# 2019-01-02    663.410000
# 2019-01-03    664.086667
# 2019-01-04    665.145000
# Name: 30ma, dtype: float64

# %%
tcs['30ma'].tail()
# Out:
# Date
# 2018-12-31    1941.741667
# 2019-01-01    1941.975000
# 2019-01-02    1942.175000
# 2019-01-03    1942.741667
# 2019-01-04    1943.708333
# Name: 30ma, dtype: float64

# %%
infy.tail(365)['Turnover (Lacs)'].plot()

# %%
infy['100ma']=infy['Close'].rolling(window=100, min_periods=0).mean()

# %%
#dataset1.tail(50)['Open'].plot()

# %%
#plt.show()

# %%
infy.tail(50)[['Open','Close']].plot()

# %%
infy.tail(50)[['Open']].plot()

# %%
tcs.tail(50)[['Open','Close']].plot()

# %%
infy.tail(50)[['Close']].plot()

# %%
#plt.show()

# %%
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
#df1.ix['2012-02-06':'2012-06-04',['INFY','WIPRO']]

# %%
#dd=df1/df1.ix[0,:]

# %%
#dd.head().plot()
